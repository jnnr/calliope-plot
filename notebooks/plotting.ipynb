# %%
# %reload_ext autoreload
# %autoreload 2
import sys

import matplotlib.pyplot as plt

import calliope
sys.path.append("..")
from src import plotting as plotting

# %%
model_name = '1_generation_consumption'
model = calliope.Model(f'../{model_name}/model.yaml')
model.run()

# %%
data = model.results.resource_con.to_pandas().T

plotting.plot_timeseries(data)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))

# %%
data = model.results.resource_con.to_pandas().T

data
plotting.plot_stacked_timeseries(data)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))

# %%
data = model.results.energy_cap.to_pandas().T
data  # region, tech, direction
# Out:
# loc_techs
# region1::ac_transmission:region2         3230.4729
# region1-3::csp                           2533.7621
# region2::demand_power                    2909.8360
# region1::free_transmission:region1-3     2280.3859
# region1::demand_power                   39033.5200
# region1::ccgt                           30000.0000
# region1-2::csp                              0.0000
# region1-3::free_transmission:region1     2280.3859
# region2::ac_transmission:region1         3230.4729
# region1-1::free_transmission:region1     9000.0000
# region2::battery                         1000.0000
# region1::free_transmission:region1-1     9000.0000
# region1::free_transmission:region1-2        0.0000
# region1-1::csp                          10000.0000
# region1-2::free_transmission:region1        0.0000
# dtype: float64

# %%
plotting.plot_stacked_bars(data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_32122/2102942330.py in ?()
# ----> 1 plotting.plot_stacked_bars(data)
#
# ~/repos/calliope-playground/notebooks/../src/plotting.py in ?(fig, ax, *args, **kwargs)
#       8     def decorated_func(*args, fig=None, ax=None, **kwargs):
#       9         if fig is None or ax is None:
#      10             fig, ax = plt.subplots()
# ---> 11         func(*args, fig=fig, ax=ax, **kwargs)
#
# ~/repos/calliope-playground/notebooks/../src/plotting.py in ?(df, fig, ax, **kwargs)
#      35 def plot_stacked_bars(df, fig=None, ax=None, **kwargs):
#      36     r"""
#      37
#      38     """
# ---> 39     df.bar(ax=ax, **kwargs)
#      40     return fig, ax
#
# ~/mambaforge/envs/calliope/lib/python3.9/site-packages/pandas/core/generic.py in ?(self, name)
#    5898             and name not in self._accessors
# ...

# %%
model._model_data.loc_coordinates.sortby("locs")
# Out:
# <xarray.DataArray 'loc_coordinates' (coordinates: 2, locs: 5)>
# array([[40, 41, 39, 39, 40],
#        [-2, -2, -1, -2, -8]])
# Coordinates:
#   * coordinates  (coordinates) object 'lat' 'lon'
#   * locs         (locs) object 'region1' 'region1-1' ... 'region1-3' 'region2'
# Attributes:
#     is_result:  0
